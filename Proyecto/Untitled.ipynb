# %%
peliculas = pd.read_csv('../Dataset/Peliculas_plataforma.csv', sep=';')
peliculas
# Out:
#           ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   13   8.8            87 %
# 1          2                      The Matrix  1999   18   8.7            87 %
# 2          3          Avengers: Infinity War  2018   13   8.5            84 %
# 3          4              Back to the Future  1985    7   8.5            96 %
# 4          5  The Good; the Bad and the Ugly  1966   18   8.8            97 %
# ...      ...                             ...   ...  ...   ...             ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2             NaN
# 16740  16741                  The Poof Point  2001    7   4.7             NaN
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7             NaN
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6             NaN
# 16743  16744                In Beaver Valley  1950  NaN   NaN             NaN
#
# ...

# %%
# Out:
#           ID                           Title  Year  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   8.8            87 %
# 1          2                      The Matrix  1999   8.7            87 %
# 2          3          Avengers: Infinity War  2018   8.5            84 %
# 3          4              Back to the Future  1985   8.5            96 %
# 4          5  The Good; the Bad and the Ugly  1966   8.8            97 %
# ...      ...                             ...   ...   ...             ...
# 16739  16740       The Ghosts of Buxley Hall  1980   6.2             NaN
# 16740  16741                  The Poof Point  2001   4.7             NaN
# 16741  16742           Sharks of Lost Island  2013   5.7             NaN
# 16742  16743              Man Among Cheetahs  2017   6.6             NaN
# 16743  16744                In Beaver Valley  1950   NaN             NaN
#
#             Genres   Plataforma
# 0           Action      Netflix
# ...

# %%
# Out:
# 0       2010-01-01
# 1       1999-01-01
# 2       2018-01-01
# 3       1985-01-01
# 4       1966-01-01
#            ...
# 16739   1980-01-01
# 16740   2001-01-01
# 16741   2013-01-01
# 16742   2017-01-01
# 16743   1950-01-01
# Name: year, Length: 16744, dtype: datetime64[ns]

# %%
# Out:
#             ID                           Title  Year  IMDb Rotten Tomatoes  \
# year
# 2010-01-01   1                       Inception  2010   8.8            87 %
# 1999-01-01   2                      The Matrix  1999   8.7            87 %
# 2018-01-01   3          Avengers: Infinity War  2018   8.5            84 %
# 1985-01-01   4              Back to the Future  1985   8.5            96 %
# 1966-01-01   5  The Good; the Bad and the Ugly  1966   8.8            97 %
#
#                Genres   Plataforma       year
# year
# 2010-01-01     Action      Netflix 2010-01-01
# 1999-01-01     Sci-Fi      Netflix 1999-01-01
# 2018-01-01     Action      Netflix 2018-01-01
# 1985-01-01  Adventure      Netflix 1985-01-01
# 1966-01-01    Western  Prime Video 1966-01-01

# %%
# Out:
#             ID                           Title  Year  IMDb Rotten Tomatoes  \
# year
# 2010-01-01   1                       Inception  2010   8.8            87 %
# 1999-01-01   2                      The Matrix  1999   8.7            87 %
# 2018-01-01   3          Avengers: Infinity War  2018   8.5            84 %
# 1985-01-01   4              Back to the Future  1985   8.5            96 %
# 1966-01-01   5  The Good; the Bad and the Ugly  1966   8.8            97 %
#
#                Genres   Plataforma
# year
# 2010-01-01     Action      Netflix
# 1999-01-01     Sci-Fi      Netflix
# 2018-01-01     Action      Netflix
# 1985-01-01  Adventure      Netflix
# 1966-01-01    Western  Prime Video
