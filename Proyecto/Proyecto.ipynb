# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer    
from nltk.tokenize import RegexpTokenizer
import numpy as np
from sklearn import preprocessing
from scipy.sparse import hstack

# %%
csv = pd.read_csv('disney plus titulos tipo genero año duracion.csv')
csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ba9de75a8800> in <module>
# ----> 1 csv = pd.read_csv('disney plus titulos tipo genero año duracion.csv')
#       2 csv
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
costerecauda.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f603e2d680c4> in <module>
# ----> 1 costerecauda.describe()
#
# NameError: name 'costerecauda' is not defined

# %%
peliplataforma = pd.read_csv('pelicula_plataforma.csv', sep= ";")
peliplataforma
# Out:
#           ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   13   8.8            87 %
# 1          2                      The Matrix  1999   18   8.7            87 %
# 2          3          Avengers: Infinity War  2018   13   8.5            84 %
# 3          4              Back to the Future  1985    7   8.5            96 %
# 4          5  The Good; the Bad and the Ugly  1966   18   8.8            97 %
# ...      ...                             ...   ...  ...   ...             ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2             NaN
# 16740  16741                  The Poof Point  2001    7   4.7             NaN
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7             NaN
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6             NaN
# 16743  16744                In Beaver Valley  1950  NaN   NaN             NaN
#
# ...

# %%
#Promedio valoracion Peliculas
nombre_archivo = 'pelicula_plataforma.csv'
with open(nombre_archivo, "r") as archivo:
    lector = csv.reader(archivo, delimiter=",")
    next(lector, None)
    sum_IMDb = 0
    sum_rotten = 0
    contador = 0
    for fila in lector:
        nombre = fila[0]
        calificacion = int(fila[1])
        precio = float(fila[2])
        suma_IMDb = IMDb
        suma_rotten = Rotten Tomatoes
        contador += 1
    print(
        f"Promedio de valoracion en IMDb es {promedio_IMDb} y promedio Rotten Tomatoes es {promedio_rotten}")

#problema no definido en Rotten ¿? Tratando de crear codigo diga valoración general
# Out:
#   File "<ipython-input-15-b1f42c1f6cea>", line 14
#     suma_rotten = Rotten Tomatoes
#                          ^
# SyntaxError: invalid syntax

# %%
#Valoracion Peliculas
Pelicula = 'pelicula_plataforma.csv'
with open(Pelicula, "r") as archivo:
    lector = csv.reader(archivo, delimiter=",")
    next(lector, None)
    for fila in lector:
        nombre = Title[2]
        IMDb = int(fila[5])
        Clasificación = float(fila[7])
        print(
            f"Peliculas: '{nombre}' con calificación {Clasificación} y valoracion en IMDb {IMDb}")
        
#problema con la importación ¿? Tratando de crear codigo que al buscar una pelicula diga la valoración
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cff720e13395> in <module>
#       2 Pelicula = 'pelicula_plataforma.csv'
#       3 with open(Pelicula, "r") as archivo:
# ----> 4     lector = csv.reader(archivo, delimiter=",")
#       5     next(lector, None)
#       6     for fila in lector:
#
# NameError: name 'csv' is not defined
